# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py

# %%
data=pd.read_csv("dataset_Facebook.csv", delimiter=";")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
data_subset_1 = data[['like','share']] #creating data subset/ data frame
data_subset_1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
data_subset_2 = data[['comment','Type']] #creating another data subset
data_subset_2
# Out:
#      comment    Type
# 0          4   Photo
# 1          5  Status
# 2          0   Photo
# 3         58   Photo
# 4         19   Photo
# ..       ...     ...
# 495        5   Photo
# 496        0   Photo
# 497        4   Photo
# 498        7   Photo
# 499        0   Photo
#
# [500 rows x 2 columns]

# %%
merged_data  = pd.merge(data_subset_2, data_subset_1, left_on='comment', right_on= 'like') #merging the two subsets
merged_data
# Out:
#       comment    Type  like  share
# 0           4   Photo   4.0    2.0
# 1           4   Photo   4.0    1.0
# 2           4   Photo   4.0    0.0
# 3           4   Photo   4.0    1.0
# 4           4  Status   4.0    2.0
# ...       ...     ...   ...    ...
# 1462       56   Photo  56.0   17.0
# 1463       56   Photo  56.0    8.0
# 1464       56   Photo  56.0   12.0
# 1465       56   Photo  56.0    9.0
# 1466       56   Photo  56.0   25.0
#
# [1467 rows x 4 columns]

# %%
merged_data.sort_values(by=['like'],ascending=False) #sorting the merged data
# Out:
#       comment   Type   like  share
# 1461      146  Photo  146.0   15.0
# 1460      146  Photo  146.0    9.0
# 1438      144  Photo  144.0   10.0
# 1439      144  Photo  144.0   29.0
# 1448       64  Photo   64.0   22.0
# ...       ...    ...    ...    ...
# 563         0  Photo    0.0    0.0
# 564         0  Photo    0.0    0.0
# 565         0  Photo    0.0    0.0
# 566         0  Photo    0.0    0.0
# 380         0  Photo    0.0    0.0
#
# [1467 rows x 4 columns]

# %%
merged_data.transpose() #transposing the merged data
# Out:
#           0      1      2      3       4       5       6       7       8     \
# comment      4      4      4      4       4       4       4       4       4
# Type     Photo  Photo  Photo  Photo  Status  Status  Status  Status  Status
# like       4.0    4.0    4.0    4.0     4.0     4.0     4.0     4.0     4.0
# share      2.0    1.0    0.0    1.0     2.0     1.0     0.0     1.0     2.0
#
#            9     ...   1457   1458   1459   1460   1461   1462   1463   1464  \
# comment       4  ...     51     51     51    146    146     56     56     56
# Type     Status  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo
# like        4.0  ...   51.0   51.0   51.0  146.0  146.0   56.0   56.0   56.0
# share       1.0  ...   11.0    6.0    6.0    9.0   15.0   17.0    8.0   12.0
#
#           1465   1466
# comment     56     56
# Type     Photo  Photo
# like      56.0   56.0
# share      9.0   25.0
#
# [4 rows x 1467 columns]

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.Type.unique() #identify unique values in the data
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
pd.melt(data, id_vars =['Type'], value_vars =['comment']) #reshaping the data
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]
